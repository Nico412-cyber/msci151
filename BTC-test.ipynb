# %% [markdown]
# <a href="https://colab.research.google.com/github/Nico412-cyber/msci151/blob/main/BTC-test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statsmodels.api as sm

# Define the dependent variable (Y) and independent variables (X)
Y = returns_data['Bitcoin']
X = returns_data[['Gold', 'Oil', 'US']]

# Add a constant (intercept) to the independent variables
X = sm.add_constant(X)

# Create and fit the OLS (Ordinary Least Squares) model
model = sm.OLS(Y, X)
results = model.fit()

# Display the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Bitcoin   R-squared:                       0.107
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     4.612
# Date:                Tue, 18 Nov 2025   Prob (F-statistic):            0.00437
# Time:                        09:58:56   Log-Likelihood:                 273.94
# No. Observations:                 120   AIC:                            -539.9
# Df Residuals:                     116   BIC:                            -528.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0024      0.002      1.014      0.313      -0.002       0.007
# ...

# %%
returns_data = pd.DataFrame()

# Define the mapping for column names
name_mapping = {
    'BTC-USD': 'Bitcoin',
    'GC=F': 'Gold',
    '^DJI': 'US',
    'CL=F': 'Oil'
}

for ticker, df in data.items():
    # Drop rows with any NaN values
    df_cleaned = df.dropna()

    # Calculate daily returns using the 'Close' price
    # Using .loc to avoid SettingWithCopyWarning
    df_cleaned.loc[:, 'Daily Returns'] = df_cleaned['Close'].pct_change()

    # Add to the returns_data DataFrame with the new descriptive name
    if ticker in name_mapping:
        returns_data[name_mapping[ticker]] = df_cleaned['Daily Returns']
    else:
        returns_data[ticker] = df_cleaned['Daily Returns']

# Drop any remaining NaN values that might result from pct_change (the first row)
returns_data = returns_data.dropna()

print("Daily Returns DataFrame (first 5 rows):")
display(returns_data.head())
# Out:
# Daily Returns DataFrame (first 5 rows):
#              Bitcoin      Gold        US       Oil
# Date
# 2025-01-03  0.012598 -0.005228  0.008017  0.011350
# 2025-01-06  0.038276 -0.002495 -0.000598 -0.005408
# 2025-01-07 -0.050504  0.006936 -0.004173  0.009380
# 2025-01-08 -0.019388  0.002936  0.002512 -0.012525
# 2025-01-10  0.023976  0.009203 -0.016342  0.035850

# %%
pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# %%
# Define the tickers and date range
tickers = ['BTC-USD', 'GC=F', '^DJI', 'CL=F']
start_date = '2025-01-01'
end_date = '2025-06-30'

# %%
# Fetch the data for each ticker
data = {}
for ticker in tickers:
    print(f"Fetching data for {ticker}...")
    try:
        df = yf.download(ticker, start=start_date, end=end_date)
        if not df.empty:
            data[ticker] = df
            print(f"Successfully fetched data for {ticker}")
        else:
            print(f"No data found for {ticker} in the specified range.")
    except Exception as e:
        print(f"Error fetching data for {ticker}: {e}")
# Out:
# Fetching data for BTC-USD...
# /tmp/ipython-input-2360167148.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-2360167148.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# Successfully fetched data for BTC-USD
# Fetching data for GC=F...
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-2360167148.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# Successfully fetched data for GC=F
# Fetching data for ^DJI...
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
# Display the first 5 rows of the Bitcoin data as an example
if 'BTC-USD' in data:
    print("\nFirst 5 rows of BTC-USD data:")
    display(data['BTC-USD'].head())
else:
    print("No data available for BTC-USD to display.")
# Out:
# First 5 rows of BTC-USD data:
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2025-01-01  94419.757812  94929.867188  92788.125000  93425.101562
# 2025-01-02  96886.875000  97739.820312  94201.570312  94416.289062
# 2025-01-03  98107.429688  98956.914062  96034.617188  96881.726562
# 2025-01-04  98236.226562  98734.429688  97562.976562  98106.992188
# 2025-01-05  98314.960938  98813.304688  97291.765625  98233.906250
#
# Price            Volume
# Ticker          BTC-USD
# Date
# 2025-01-01  24519888919
# 2025-01-02  46009564411
# 2025-01-03  35611391163
# 2025-01-04  22342608078
# 2025-01-05  20525254825
