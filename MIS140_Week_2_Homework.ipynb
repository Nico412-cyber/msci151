# %% [markdown]
# <a href="https://colab.research.google.com/github/Nico412-cyber/msci151/blob/main/MIS140_Week_2_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **HOMEWORK**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
url = '/content/MIS140_GlideWise360_data.csv'
df = pd.read_csv(url)

# %%
df
# Out:
#           RecordID Shift_Manager_Code        Date  Year Month  Hour  \
# 0     1.010120e+08              SM-10    1/1/2011  2011   Jan     0
# 1     2.010120e+08              SM-11    1/1/2011  2011   Jan     1
# 2     3.010120e+08              SM-02    1/1/2011  2011   Jan     2
# 3     4.010120e+08              SM-02    1/1/2011  2011   Jan     3
# 4     5.010120e+08              SM-09    1/1/2011  2011   Jan     4
# ...            ...                ...         ...   ...   ...   ...
# 8640  8.640000e+11              SM-11  31/12/2011  2011   Dec    19
# 8641  8.640000e+11              SM-06  31/12/2011  2011   Dec    20
# 8642  8.640000e+11              SM-10  31/12/2011  2011   Dec    21
# 8643  8.640000e+11              SM-12  31/12/2011  2011   Dec    22
# 8644  8.650000e+11              SM-07  31/12/2011  2011   Dec    23
#
#      Session_colour Weather_Outcast  Temperature_Celsius  \
# 0               red           Clear                  3.3
# 1             black           Clear                  2.3
# 2              blue           Clear                  2.3
# 3             green           Clear                  3.3
# 4             black           Clear                  3.3
# ...             ...             ...                  ...
# 8640         purple           Clear                 11.7
# 8641          white           Clear                 11.7
# 8642          green           Clear                 10.8
# 8643          green           Clear                  9.9
# 8644            red           Clear                  8.9
#
#       Feeling_Temperature_Celsius  Humidity_Percent  Wind_Speed_kph  Season  \
# 0                               3                81               0  Winter
# 1                               2                80               0  Winter
# 2                               2                80               0  Winter
# 3                               3                75               0  Winter
# 4                               3                75               0  Winter
# ...                           ...               ...             ...     ...
# 8640                           12                54              15  Winter
# 8641                           12                54              15  Winter
# 8642                           11                58              13  Winter
# 8643                           10                62               9  Winter
# 8644                            9                66               0  Winter
#
#      Public_Holiday  Week_Day Business_Day  Registered_Member_Count  \
# 0               Yes  Saturday           No                       13
# 1               Yes  Saturday           No                       32
# 2               Yes  Saturday           No                       27
# 3               Yes  Saturday           No                       10
# 4               Yes  Saturday           No                        1
# ...             ...       ...          ...                      ...
# 8640             No  Saturday           No                       73
# 8641             No  Saturday           No                       63
# 8642             No  Saturday           No                       50
# 8643             No  Saturday           No                       36
# 8644             No  Saturday           No                       27
#
#       Casual_User_Count  Rental_Bikes_Total
# 0                   NaN                  16
# 1                   8.0                  40
# 2                   5.0                  32
# 3                   3.0                  13
# 4                   0.0                   1
# ...                 ...                 ...
# 8640               19.0                  92
# 8641                8.0                  71
# 8642                2.0                  52
# 8643                2.0                  38
# 8644                4.0                  31
#
# [8645 rows x 19 columns]

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8645 entries, 0 to 8644
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   RecordID                     8645 non-null   float64
#  1   Shift_Manager_Code           8645 non-null   object
#  2   Date                         8645 non-null   object
#  3   Year                         8645 non-null   int64
#  4   Month                        8645 non-null   object
#  5   Hour                         8645 non-null   int64
#  6   Session_colour               8532 non-null   object
#  7   Weather_Outcast              8645 non-null   object
#  8   Temperature_Celsius          8645 non-null   float64
#  9   Feeling_Temperature_Celsius  8645 non-null   int64
#  10  Humidity_Percent             8645 non-null   int64
#  11  Wind_Speed_kph               8645 non-null   int64
#  12  Season                       8645 non-null   object
#  13  Public_Holiday               8645 non-null   object
#  14  Week_Day                     8645 non-null   object
#  15  Business_Day                 8645 non-null   object
#  16  Registered_Member_Count      8645 non-null   int64
#  17  Casual_User_Count            8558 non-null   float64
#  18  Rental_Bikes_Total           8645 non-null   int64
# dtypes: float64(3), int64(7), object(9)
# memory usage: 1.3+ MB
#            RecordID    Year         Hour  Temperature_Celsius  \
# count  8.645000e+03  8645.0  8645.000000          8645.000000
# mean   4.323456e+11  2011.0    11.573626            14.991209
# std    2.495808e+11     0.0     6.907822             9.333185
# min    1.010120e+08  2011.0     0.000000            -7.100000
# 25%    2.160000e+11  2011.0     6.000000             7.000000
# 50%    4.320000e+11  2011.0    12.000000            15.500000
# 75%    6.480000e+11  2011.0    18.000000            23.000000
# max    8.650000e+11  2011.0    23.000000            85.000000
#
#        Feeling_Temperature_Celsius  Humidity_Percent  Wind_Speed_kph  \
# count                  8645.000000       8645.000000     8645.000000
# mean                     14.953962         64.350029       12.825564
# std                      11.665929         19.643758        8.383611
# min                     -16.000000          0.000000        0.000000
# 25%                       5.000000         49.000000        7.000000
# 50%                      16.000000         65.000000       13.000000
# 75%                      25.000000         81.000000       19.000000
# max                      50.000000        135.000000      150.000000
#
#        Registered_Member_Count  Casual_User_Count  Rental_Bikes_Total
# count              8645.000000        8558.000000         8645.000000
# mean                115.193869          47.813157          143.794448
# std                 109.461014         400.877584          133.797854
# min                   0.000000         -15.000000            1.000000
# 25%                  26.000000           3.000000           31.000000
# 50%                  90.000000          14.000000          109.000000
# 75%                 168.000000          39.000000          211.000000
# max                 567.000000        9999.000000          651.000000

# %%
print(df.shape)

print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
# Out:
# (8645, 19)
# Number of rows: 8645
# Number of columns: 19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8645 entries, 0 to 8644
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   RecordID                     8645 non-null   float64
#  1   Shift_Manager_Code           8645 non-null   object
#  2   Date                         8645 non-null   object
#  3   Year                         8645 non-null   int64
#  4   Month                        8645 non-null   object
#  5   Hour                         8645 non-null   int64
#  6   Session_colour               8532 non-null   object
#  7   Weather_Outcast              8645 non-null   object
#  8   Temperature_Celsius          8645 non-null   float64
#  9   Feeling_Temperature_Celsius  8645 non-null   int64
#  10  Humidity_Percent             8645 non-null   int64
#  11  Wind_Speed_kph               8645 non-null   int64
#  12  Season                       8645 non-null   object
#  13  Public_Holiday               8645 non-null   object
#  14  Week_Day                     8645 non-null   object
#  15  Business_Day                 8645 non-null   object
#  16  Registered_Member_Count      8645 non-null   int64
#  17  Casual_User_Count            8558 non-null   float64
#  18  Rental_Bikes_Total           8645 non-null   int64
# dtypes: float64(3), int64(7), object(9)
# memory usage: 1.3+ MB

# %%
df.isna().sum()
# Out:
# RecordID                         0
# Shift_Manager_Code               0
# Date                             0
# Year                             0
# Month                            0
# Hour                             0
# Session_colour                 113
# Weather_Outcast                  0
# Temperature_Celsius              0
# Feeling_Temperature_Celsius      0
# Humidity_Percent                 0
# Wind_Speed_kph                   0
# Season                           0
# Public_Holiday                   0
# Week_Day                         0
# Business_Day                     0
# Registered_Member_Count          0
# Casual_User_Count               87
# Rental_Bikes_Total               0
# dtype: int64

# %%
df.describe()
# Out:
#            RecordID    Year         Hour  Session_colour  Temperature_Celsius  \
# count  8.645000e+03  8645.0  8645.000000             0.0          8645.000000
# mean   4.323456e+11  2011.0    11.573626             NaN            14.991209
# std    2.495808e+11     0.0     6.907822             NaN             9.333185
# min    1.010120e+08  2011.0     0.000000             NaN            -7.100000
# 25%    2.160000e+11  2011.0     6.000000             NaN             7.000000
# 50%    4.320000e+11  2011.0    12.000000             NaN            15.500000
# 75%    6.480000e+11  2011.0    18.000000             NaN            23.000000
# max    8.650000e+11  2011.0    23.000000             NaN            85.000000
#
#        Feeling_Temperature_Celsius  Humidity_Percent  Wind_Speed_kph  \
# count                  8645.000000       8645.000000     8645.000000
# mean                     14.953962         64.350029       12.825564
# std                      11.665929         19.643758        8.383611
# min                     -16.000000          0.000000        0.000000
# 25%                       5.000000         49.000000        7.000000
# 50%                      16.000000         65.000000       13.000000
# 75%                      25.000000         81.000000       19.000000
# max                      50.000000        135.000000      150.000000
#
#        Registered_Member_Count  Casual_User_Count  Rental_Bikes_Total
# count              8645.000000        8558.000000         8645.000000
# mean                115.193869          47.813157          143.794448
# std                 109.461014         400.877584          133.797854
# min                   0.000000         -15.000000            1.000000
# 25%                  26.000000           3.000000           31.000000
# 50%                  90.000000          14.000000          109.000000
# 75%                 168.000000          39.000000          211.000000
# max                 567.000000        9999.000000          651.000000

# %%
# Convert 'Session_colour' column to numeric, forcing errors to NaN
df['Session_colour'] = pd.to_numeric(df['Session_colour'], errors='coerce')
df['Casual_User_Count'] = pd.to_numeric(df['Casual_User_Count'], errors='coerce')

# %%
df.isna().sum()
# Out:
# RecordID                          0
# Shift_Manager_Code                0
# Date                              0
# Year                              0
# Month                             0
# Hour                              0
# Session_colour                 8645
# Weather_Outcast                   0
# Temperature_Celsius               0
# Feeling_Temperature_Celsius       0
# Humidity_Percent                  0
# Wind_Speed_kph                    0
# Season                            0
# Public_Holiday                    0
# Week_Day                          0
# Business_Day                      0
# Registered_Member_Count           0
# Casual_User_Count                87
# Rental_Bikes_Total                0
# dtype: int64

# %%
df
# Out:
#           RecordID Shift_Manager_Code        Date  Year Month  Hour  \
# 0     1.010120e+08              SM-10    1/1/2011  2011   Jan     0
# 1     2.010120e+08              SM-11    1/1/2011  2011   Jan     1
# 2     3.010120e+08              SM-02    1/1/2011  2011   Jan     2
# 3     4.010120e+08              SM-02    1/1/2011  2011   Jan     3
# 4     5.010120e+08              SM-09    1/1/2011  2011   Jan     4
# ...            ...                ...         ...   ...   ...   ...
# 8640  8.640000e+11              SM-11  31/12/2011  2011   Dec    19
# 8641  8.640000e+11              SM-06  31/12/2011  2011   Dec    20
# 8642  8.640000e+11              SM-10  31/12/2011  2011   Dec    21
# 8643  8.640000e+11              SM-12  31/12/2011  2011   Dec    22
# 8644  8.650000e+11              SM-07  31/12/2011  2011   Dec    23
#
#       Session_colour Weather_Outcast  Temperature_Celsius  \
# 0                NaN           Clear                  3.3
# 1                NaN           Clear                  2.3
# 2                NaN           Clear                  2.3
# 3                NaN           Clear                  3.3
# 4                NaN           Clear                  3.3
# ...              ...             ...                  ...
# 8640             NaN           Clear                 11.7
# 8641             NaN           Clear                 11.7
# 8642             NaN           Clear                 10.8
# 8643             NaN           Clear                  9.9
# 8644             NaN           Clear                  8.9
#
#       Feeling_Temperature_Celsius  Humidity_Percent  Wind_Speed_kph  Season  \
# 0                               3                81               0  Winter
# 1                               2                80               0  Winter
# 2                               2                80               0  Winter
# 3                               3                75               0  Winter
# 4                               3                75               0  Winter
# ...                           ...               ...             ...     ...
# 8640                           12                54              15  Winter
# 8641                           12                54              15  Winter
# 8642                           11                58              13  Winter
# 8643                           10                62               9  Winter
# 8644                            9                66               0  Winter
#
#      Public_Holiday  Week_Day Business_Day  Registered_Member_Count  \
# 0               Yes  Saturday           No                       13
# 1               Yes  Saturday           No                       32
# 2               Yes  Saturday           No                       27
# 3               Yes  Saturday           No                       10
# 4               Yes  Saturday           No                        1
# ...             ...       ...          ...                      ...
# 8640             No  Saturday           No                       73
# 8641             No  Saturday           No                       63
# 8642             No  Saturday           No                       50
# 8643             No  Saturday           No                       36
# 8644             No  Saturday           No                       27
#
#       Casual_User_Count  Rental_Bikes_Total
# 0                   NaN                  16
# 1                   8.0                  40
# 2                   5.0                  32
# 3                   3.0                  13
# 4                   0.0                   1
# ...                 ...                 ...
# 8640               19.0                  92
# 8641                8.0                  71
# 8642                2.0                  52
# 8643                2.0                  38
# 8644                4.0                  31
#
# [8645 rows x 19 columns]

# %%
# Convert 'Date' to datetime format
df['Date'] = pd.to_datetime(df['Date'].astype(str).str.strip(), format='%d/%m/%Y', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8645 entries, 0 to 8644
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   RecordID                     8645 non-null   float64
#  1   Shift_Manager_Code           8645 non-null   object
#  2   Date                         0 non-null      datetime64[ns]
#  3   Year                         8645 non-null   int64
#  4   Month                        8645 non-null   object
#  5   Hour                         8645 non-null   int64
#  6   Session_colour               0 non-null      float64
#  7   Weather_Outcast              8645 non-null   object
#  8   Temperature_Celsius          8645 non-null   float64
#  9   Feeling_Temperature_Celsius  8645 non-null   int64
#  10  Humidity_Percent             8645 non-null   int64
#  11  Wind_Speed_kph               8645 non-null   int64
#  12  Season                       8645 non-null   object
#  13  Public_Holiday               8645 non-null   object
#  14  Week_Day                     8645 non-null   object
#  15  Business_Day                 8645 non-null   object
#  16  Registered_Member_Count      8645 non-null   int64
#  17  Casual_User_Count            8558 non-null   float64
#  18  Rental_Bikes_Total           8645 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(7), object(7)
# memory usage: 1.3+ MB

# %%
import matplotlib.pyplot as plt

# Group data by month and count occurrences
# The 'Year' column is an integer and does not support the .dt accessor.
# The 'Date' column is the correct column to use for period grouping,
# but it first needs to be correctly parsed as datetime objects in cell HLh2O7HNduZ_.
# Make sure to update the format string in cell HLh2O7HNduZ_ to '%d/%m/%Y' and re-run it.
df_grouped = df.groupby(df['Date'].dt.to_period("M")).size()

# Plot
plt.figure(figsize=(10,5))
df_grouped.plot(kind='line', marker='o')
plt.xlabel("Month")
plt.ylabel("Count")
plt.title("Total Membership")
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-593868165.py in <cell line: 0>()
#       2
#       3 # Group data by month and count occurrences
# ----> 4 df_grouped = df.groupby(df['Year'].dt.to_period("M")).size()
#       5
#       6 # Plot
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     641             return PeriodProperties(data, orig)
#     642
# --> 643         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
# Convert 'Date' to datetime format
df['Date'] = pd.to_datetime(df['Date'].astype(str).str.strip(), format='%d/%m/%Y', errors='coerce')

# %%
import matplotlib.pyplot as plt

# Group data by month and count occurrences
df_grouped = df.groupby(df['Date'].dt.to_period("M")).size()

# Plot
plt.figure(figsize=(10,5))
df_grouped.plot(kind='line', marker='o')
plt.xlabel("Month")
plt.ylabel("Count")
plt.title("Total Membership")
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8645 entries, 0 to 8644
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   RecordID                     8645 non-null   float64
#  1   Shift_Manager_Code           8645 non-null   object
#  2   Date                         0 non-null      datetime64[ns]
#  3   Year                         8645 non-null   int64
#  4   Month                        8645 non-null   object
#  5   Hour                         8645 non-null   int64
#  6   Session_colour               0 non-null      float64
#  7   Weather_Outcast              8645 non-null   object
#  8   Temperature_Celsius          8645 non-null   float64
#  9   Feeling_Temperature_Celsius  8645 non-null   int64
#  10  Humidity_Percent             8645 non-null   int64
#  11  Wind_Speed_kph               8645 non-null   int64
#  12  Season                       8645 non-null   object
#  13  Public_Holiday               8645 non-null   object
#  14  Week_Day                     8645 non-null   object
#  15  Business_Day                 8645 non-null   object
#  16  Registered_Member_Count      8645 non-null   int64
#  17  Casual_User_Count            8558 non-null   float64
#  18  Rental_Bikes_Total           8645 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(7), object(7)
# memory usage: 1.3+ MB

# %%
url = '/content/MIS140_GlideWise360_data.csv'

# Load the dataset into a pandas DataFrame
df = pd.read_csv(url)

# %%
# Convert 'Date' to datetime format
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, errors='coerce')

# %%
# Check the total number of missing values per column
df.isnull().sum()
# Out:
# RecordID                         0
# Shift_Manager_Code               0
# Date                             0
# Year                             0
# Month                            0
# Hour                             0
# Session_colour                 113
# Weather_Outcast                  0
# Temperature_Celsius              0
# Feeling_Temperature_Celsius      0
# Humidity_Percent                 0
# Wind_Speed_kph                   0
# Season                           0
# Public_Holiday                   0
# Week_Day                         0
# Business_Day                     0
# Registered_Member_Count          0
# Casual_User_Count               87
# Rental_Bikes_Total               0
# dtype: int64

# %%
# Check the total number of missing values per column sorted by descending order
df.isnull().sum().sort_values(ascending=False)
# Out:
# Session_colour                 113
# Casual_User_Count               87
# RecordID                         0
# Date                             0
# Shift_Manager_Code               0
# Month                            0
# Year                             0
# Weather_Outcast                  0
# Temperature_Celsius              0
# Feeling_Temperature_Celsius      0
# Hour                             0
# Humidity_Percent                 0
# Wind_Speed_kph                   0
# Public_Holiday                   0
# Season                           0
# Week_Day                         0
# Business_Day                     0
# Registered_Member_Count          0
# Rental_Bikes_Total               0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot missing values as a heatmap
plt.figure(figsize=(10, 5))
sns.heatmap(df.isnull(), cmap="viridis", cbar=False, yticklabels=False)
plt.title("Missing Data Heatmap")
plt.show()

# %%
# Display the rows that contain missing values
df[df.isnull().any(axis=1)]
# Out:
#           RecordID Shift_Manager_Code       Date  Year Month  Hour  \
# 0     1.010120e+08              SM-10 2011-01-01  2011   Jan     0
# 9     1.001012e+09              SM-05 2011-01-01  2011   Jan     9
# 54    5.503012e+09              SM-05 2011-01-03  2011   Jan     9
# 62    6.303012e+09              SM-13 2011-01-03  2011   Jan    17
# 71    7.204012e+09              SM-11 2011-01-04  2011   Jan     2
# ...            ...                ...        ...   ...   ...   ...
# 8508  8.510000e+11              SM-03 2011-12-26  2011   Dec     6
# 8557  8.560000e+11              SM-11 2011-12-28  2011   Dec     8
# 8571  8.570000e+11              SM-03 2011-12-28  2011   Dec    22
# 8582  8.580000e+11              SM-11 2011-12-29  2011   Dec     9
# 8589  8.590000e+11              SM-14 2011-12-29  2011   Dec    16
#
#      Session_colour  Weather_Outcast  Temperature_Celsius  \
# 0               red            Clear                  3.3
# 9               NaN            Clear                  7.0
# 54              NaN            Clear                 -0.5
# 62            green            Clear                  3.3
# 71            green            Clear                 -1.4
# ...             ...              ...                  ...
# 8508          white            Clear                  7.0
# 8557            NaN            Clear                  7.0
# 8571           blue            Clear                  2.3
# 8582            red  Mist and Cloudy                  1.4
# 8589            NaN            Clear                  6.1
#
#       Feeling_Temperature_Celsius  Humidity_Percent  Wind_Speed_kph  Season  \
# 0                               3                81               0  Winter
# 9                               7                76               0  Winter
# 54                             -7                43              26  Winter
# 62                             -1                30              15  Winter
# 71                             -6                63               9  Winter
# ...                           ...               ...             ...     ...
# 8508                            4                45              19  Winter
# 8557                            3                57              24  Winter
# 8571                            0                44               7  Winter
# 8582                           -2                64               9  Winter
# 8589                            4                52              11  Winter
#
#      Public_Holiday   Week_Day Business_Day  Registered_Member_Count  \
# 0               Yes   Saturday           No                       13
# 9               Yes   Saturday           No                        6
# 54               No     Monday          yes                       81
# 62               No     Monday          yes                      146
# 71               No    Tuesday          yes                        1
# ...             ...        ...          ...                      ...
# 8508            Yes     Monday           No                        4
# 8557             No  Wednesday          yes                      206
# 8571             No  Wednesday          yes                       31
# 8582             No   Thursday          yes                      155
# 8589             No   Thursday          yes                      155
#
#       Casual_User_Count  Rental_Bikes_Total
# 0                   NaN                  16
# 9                   8.0                  14
# 54                  7.0                  88
# 62                  NaN                 157
# 71                  NaN                   1
# ...                 ...                 ...
# 8508                NaN                   4
# 8557               11.0                 217
# 8571                NaN                  33
# 8582                NaN                 170
# 8589               22.0                 177
#
# [198 rows x 19 columns]

# %%
df.dropna()
# Out:
#           RecordID Shift_Manager_Code       Date  Year Month  Hour  \
# 1     2.010120e+08              SM-11 2011-01-01  2011   Jan     1
# 2     3.010120e+08              SM-02 2011-01-01  2011   Jan     2
# 3     4.010120e+08              SM-02 2011-01-01  2011   Jan     3
# 4     5.010120e+08              SM-09 2011-01-01  2011   Jan     4
# 5     6.010120e+08              SM-12 2011-01-01  2011   Jan     5
# ...            ...                ...        ...   ...   ...   ...
# 8640  8.640000e+11              SM-11 2011-12-31  2011   Dec    19
# 8641  8.640000e+11              SM-06 2011-12-31  2011   Dec    20
# 8642  8.640000e+11              SM-10 2011-12-31  2011   Dec    21
# 8643  8.640000e+11              SM-12 2011-12-31  2011   Dec    22
# 8644  8.650000e+11              SM-07 2011-12-31  2011   Dec    23
#
#      Session_colour  Weather_Outcast  Temperature_Celsius  \
# 1             black            Clear                  2.3
# 2              blue            Clear                  2.3
# 3             green            Clear                  3.3
# 4             black            Clear                  3.3
# 5             black  Mist and Cloudy                  3.3
# ...             ...              ...                  ...
# 8640         purple            Clear                 11.7
# 8641          white            Clear                 11.7
# 8642          green            Clear                 10.8
# 8643          green            Clear                  9.9
# 8644            red            Clear                  8.9
#
#       Feeling_Temperature_Celsius  Humidity_Percent  Wind_Speed_kph  Season  \
# 1                               2                80               0  Winter
# 2                               2                80               0  Winter
# 3                               3                75               0  Winter
# 4                               3                75               0  Winter
# 5                               1                75               6  Winter
# ...                           ...               ...             ...     ...
# 8640                           12                54              15  Winter
# 8641                           12                54              15  Winter
# 8642                           11                58              13  Winter
# 8643                           10                62               9  Winter
# 8644                            9                66               0  Winter
#
#      Public_Holiday  Week_Day Business_Day  Registered_Member_Count  \
# 1               Yes  Saturday           No                       32
# 2               Yes  Saturday           No                       27
# 3               Yes  Saturday           No                       10
# 4               Yes  Saturday           No                        1
# 5               Yes  Saturday           No                        1
# ...             ...       ...          ...                      ...
# 8640             No  Saturday           No                       73
# 8641             No  Saturday           No                       63
# 8642             No  Saturday           No                       50
# 8643             No  Saturday           No                       36
# 8644             No  Saturday           No                       27
#
#       Casual_User_Count  Rental_Bikes_Total
# 1                   8.0                  40
# 2                   5.0                  32
# 3                   3.0                  13
# 4                   0.0                   1
# 5                   0.0                   1
# ...                 ...                 ...
# 8640               19.0                  92
# 8641                8.0                  71
# 8642                2.0                  52
# 8643                2.0                  38
# 8644                4.0                  31
#
# [8447 rows x 19 columns]

# %%
# Replace ['Session_colour'] with its mode (most frequent value) for categorical data
df["Session_colour"] = df["Session_colour"].fillna(df["Session_colour"].mode()[0])
# Correcting typo in column name and filling with median for numerical data
df["Casual_User_Count"] = df["Casual_User_Count"].fillna(df["Casual_User_Count"].median())

# %%
# Check for duplicate rows
duplicates = df.duplicated()
df[duplicates]
# Out:
# Empty DataFrame
# Columns: [RecordID, Shift_Manager_Code, Date, Year, Month, Hour, Session_colour, Weather_Outcast, Temperature_Celsius, Feeling_Temperature_Celsius, Humidity_Percent, Wind_Speed_kph, Season, Public_Holiday, Week_Day, Business_Day, Registered_Member_Count, Casual_User_Count, Rental_Bikes_Total]
# Index: []

# %%
# Sumiing duplicated data
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Create a DataFrame with some duplicates and some unique names
data = {
    'First Name': ['John', 'Jane', 'John', 'Alice', 'Jane', 'John', 'Alice', 'Mark', 'Sarah'],
    'Last Name': ['Doe', 'Smith', 'Doe', 'Brown', 'Smith', 'Doe', 'Green', 'Taylor', 'Lee'],
    'Age': [30, 25, 30, 40, 25, 35, 45, 50, 28]  # Extra column for variety
}

df_name = pd.DataFrame(data)

print('Original DF')
print(df_name)


# Define the columns to check for duplicates (First Name, Last Name)
cols_to_check = ['First Name', 'Last Name']

# Find duplicate rows based on the combination of first and last name
df_dupes = df_name[df_name.duplicated(subset=cols_to_check, keep=False)]
print('\nDuplicated DF')

print(df_dupes)
# Out:
# Original DF
#   First Name Last Name  Age
# 0       John       Doe   30
# 1       Jane     Smith   25
# 2       John       Doe   30
# 3      Alice     Brown   40
# 4       Jane     Smith   25
# 5       John       Doe   35
# 6      Alice     Green   45
# 7       Mark    Taylor   50
# 8      Sarah       Lee   28
#
# Duplicated DF
#   First Name Last Name  Age
# 0       John       Doe   30
# 1       Jane     Smith   25
# 2       John       Doe   30
# 4       Jane     Smith   25
# 5       John       Doe   35

# %%
df.drop_duplicates()
# Out:
#           RecordID Shift_Manager_Code       Date  Year Month  Hour  \
# 0     1.010120e+08              SM-10 2011-01-01  2011   Jan     0
# 1     2.010120e+08              SM-11 2011-01-01  2011   Jan     1
# 2     3.010120e+08              SM-02 2011-01-01  2011   Jan     2
# 3     4.010120e+08              SM-02 2011-01-01  2011   Jan     3
# 4     5.010120e+08              SM-09 2011-01-01  2011   Jan     4
# ...            ...                ...        ...   ...   ...   ...
# 8640  8.640000e+11              SM-11 2011-12-31  2011   Dec    19
# 8641  8.640000e+11              SM-06 2011-12-31  2011   Dec    20
# 8642  8.640000e+11              SM-10 2011-12-31  2011   Dec    21
# 8643  8.640000e+11              SM-12 2011-12-31  2011   Dec    22
# 8644  8.650000e+11              SM-07 2011-12-31  2011   Dec    23
#
#      Session_colour Weather_Outcast  Temperature_Celsius  \
# 0               red           Clear                  3.3
# 1             black           Clear                  2.3
# 2              blue           Clear                  2.3
# 3             green           Clear                  3.3
# 4             black           Clear                  3.3
# ...             ...             ...                  ...
# 8640         purple           Clear                 11.7
# 8641          white           Clear                 11.7
# 8642          green           Clear                 10.8
# 8643          green           Clear                  9.9
# 8644            red           Clear                  8.9
#
#       Feeling_Temperature_Celsius  Humidity_Percent  Wind_Speed_kph  Season  \
# 0                               3                81               0  Winter
# 1                               2                80               0  Winter
# 2                               2                80               0  Winter
# 3                               3                75               0  Winter
# 4                               3                75               0  Winter
# ...                           ...               ...             ...     ...
# 8640                           12                54              15  Winter
# 8641                           12                54              15  Winter
# 8642                           11                58              13  Winter
# 8643                           10                62               9  Winter
# 8644                            9                66               0  Winter
#
#      Public_Holiday  Week_Day Business_Day  Registered_Member_Count  \
# 0               Yes  Saturday           No                       13
# 1               Yes  Saturday           No                       32
# 2               Yes  Saturday           No                       27
# 3               Yes  Saturday           No                       10
# 4               Yes  Saturday           No                        1
# ...             ...       ...          ...                      ...
# 8640             No  Saturday           No                       73
# 8641             No  Saturday           No                       63
# 8642             No  Saturday           No                       50
# 8643             No  Saturday           No                       36
# 8644             No  Saturday           No                       27
#
#       Casual_User_Count  Rental_Bikes_Total
# 0                  14.0                  16
# 1                   8.0                  40
# 2                   5.0                  32
# 3                   3.0                  13
# 4                   0.0                   1
# ...                 ...                 ...
# 8640               19.0                  92
# 8641                8.0                  71
# 8642                2.0                  52
# 8643                2.0                  38
# 8644                4.0                  31
#
# [8645 rows x 19 columns]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# Sample dataset
data = {
    'Salary': [25000, 50000, 75000, 100000, 125000, 150000, 175000, 200000, 1000000]  # Includes an extreme outlier
}
df_salary = pd.DataFrame(data)

# Apply Min-Max Scaling (0-1 scaling)
minmax_scaler = MinMaxScaler()
df_salary['Salary_MinMax'] = minmax_scaler.fit_transform(df_salary[['Salary']])

# Apply Z-score Standardisation (Mean = 0, Std = 1)
standard_scaler = StandardScaler()
df_salary['Salary_ZScore'] = standard_scaler.fit_transform(df_salary[['Salary']])

# Apply Robust Scaling (Median-centered, IQR-based scaling)
robust_scaler = RobustScaler()
df_salary['Salary_Robust'] = robust_scaler.fit_transform(df_salary[['Salary']])

# Display the results
print(df_salary)
# Out:
#     Salary  Salary_MinMax  Salary_ZScore  Salary_Robust
# 0    25000       0.000000      -0.655102          -1.00
# 1    50000       0.025641      -0.567103          -0.75
# 2    75000       0.051282      -0.479104          -0.50
# 3   100000       0.076923      -0.391106          -0.25
# 4   125000       0.102564      -0.303107           0.00
# 5   150000       0.128205      -0.215108           0.25
# 6   175000       0.153846      -0.127109           0.50
# 7   200000       0.179487      -0.039111           0.75
# 8  1000000       1.000000       2.776850           8.75

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder

# Sample dataset with ordinal categories
df_ordinal = pd.DataFrame({
    'Satisfaction': ['Low', 'Medium', 'High', 'Low', 'High'],
    'Membership': ['Bronze', 'Silver', 'Gold', 'Silver', 'Gold']
})

# Define the order for ordinal categories
category_orders = [
    ['Low', 'Medium', 'High'],   # Order for 'Satisfaction'
    ['Bronze', 'Silver', 'Gold'] # Order for 'Membership'
]

# Initialize and apply Ordinal Encoding
encoder = OrdinalEncoder(categories=category_orders)
df_ordinal[['Satisfaction_Encoded', 'Membership_Encoded']] = encoder.fit_transform(df_ordinal[['Satisfaction', 'Membership']])

print(df_ordinal)
# Out:
#   Satisfaction Membership  Satisfaction_Encoded  Membership_Encoded
# 0          Low     Bronze                   0.0                 0.0
# 1       Medium     Silver                   1.0                 1.0
# 2         High       Gold                   2.0                 2.0
# 3          Low     Silver                   0.0                 1.0
# 4         High       Gold                   2.0                 2.0

# %%
# Sample dataset with nominal categories
df_nominal = pd.DataFrame({'City': ['New York', 'London', 'Tokyo', 'London', 'Tokyo']})

# Apply One-Hot Encoding
df_encoded = pd.get_dummies(df_nominal, columns=['City'])

print(df_encoded)
# Out:
#    City_London  City_New York  City_Tokyo
# 0        False           True       False
# 1         True          False       False
# 2        False          False        True
# 3         True          False       False
# 4        False          False        True

# %%
df_one_hot_drop_first = pd.get_dummies(df_nominal, columns=['City'], drop_first=True)
print(df_one_hot_drop_first)
# Out:
#    City_New York  City_Tokyo
# 0           True       False
# 1          False       False
# 2          False        True
# 3          False       False
# 4          False        True

# %%
# Save the cleaned dataset as a CSV file
df.to_csv("cleaned_data.csv", index=False)

# %%
df = pd.read_csv("/content/MIS140_GlideWise360_data.csv")
