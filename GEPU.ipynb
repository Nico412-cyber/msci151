# %% [markdown]
# <a href="https://colab.research.google.com/github/Nico412-cyber/msci151/blob/main/GEPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statsmodels.formula.api as smf

# Define the regression formula: Y ~ X (US ~ GEPU)
# An intercept is included by default in statsmodels OLS
model = smf.ols('US ~ GEPU', data=df)

# Fit the model
results = model.fit()

# Display the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     US   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 4.696e+04
# Date:                Tue, 18 Nov 2025   Prob (F-statistic):               0.00
# Time:                        09:41:49   Log-Likelihood:                -1171.1
# No. Observations:                 345   AIC:                             2346.
# Df Residuals:                     343   BIC:                             2354.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6167      0.785      0.785      0.433      -0.928       2.161
# ...

# %%
import pandas as pd

excel_file_path = '/content/sample_data/GEPU Test W8.xlsx'
df = pd.read_excel(excel_file_path)
display(df.head())
# Out:
#    Year  Month       GEPU         US
# 0  1997      1  75.585468  78.571181
# 1  1997      2  76.104192  75.664773
# 2  1997      3  66.568757  64.209641
# 3  1997      4  71.689527  71.701273
# 4  1997      5  75.359957  82.298050
